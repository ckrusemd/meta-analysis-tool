# %% [markdown]
# # Grab Pubmed Abstracts

# %% [markdown]
# ## Functions

# %%
from Bio import Entrez
import json
from bs4 import BeautifulSoup as bs
import lxml
import json
import numpy as np
from tqdm import tqdm
import pandas as pd
import semanticscholar as sch

# %%
def entrez_search_pubmed(query,records_per_query=10,email="XXX@YYY.com",retMax=100):
    from Bio import Entrez
    Entrez.email = email
    # Search
    handle = Entrez.esearch(db="pubmed",term=query, idtype="acc", retMax=retMax)
    record = Entrez.read(handle)
    handle.close()
    return record

# %%
def flatten_abstract(abstract_xml):
    abstract = ''
    for abstractText in abstract_xml.find_all('abstracttext'):
        if abstractText.get('label') != None:
            abstract = abstract + " " + abstractText.get('label') + ": "
        abstract = abstract + abstractText.text
    return abstract

# %%
def entrez_fetch_abstracts(uid,email):
    from Bio import Entrez
    from bs4 import BeautifulSoup as bs
    Entrez.email = email
    handle = Entrez.efetch(db="pubmed", id=uid, rettype='Medline', retmode='xml')
    result = handle.readlines()
    result = b"".join(result)
    bs_content = bs(result, "lxml")
    abstracts = bs_content.find_all('abstract')
    handle.close()
    # Abstract
    results = [ flatten_abstract(abstract) for abstract in abstracts]
    return results

# %%
def entrez_construct_abstract_dict(uids,email):
        results = entrez_fetch_abstracts( uids, email )
        return [{'uid':a, 'abstract':b, 'include':''} for a,b in zip(uids, results)]

# %%
def entrez_fetch_list_summary(uid_list):
    from Bio import Entrez
    results = [ Entrez.read( Entrez.esummary(db="pubmed", id=uid) ) for uid in uid_list ]
    return results

# %% [markdown]
# ## Query

# %%
query_body={ "query": "\"COVID-19\"[Mesh]", 'email' : "XXX@YYY.com" }
## Query search
results_query = entrez_search_pubmed(query = query_body['query'], email = query_body['email'], retMax=200)

# %%
uids = results_query['IdList']
len(uids)
# Out:
# 200

# %% [markdown]
# # Citations by DOI

# %%
result_summaries = entrez_fetch_list_summary(uids)

# %%
def citations_from_doi(doi):
    return sch.paper('10.1371/journal.pone.0251960', timeout=2)['numCitedBy']

# %%
def extract_epub_doi(summary):
    try:
        return { 'uid':summary['Id'], 'EPubDate': summary['EPubDate'], 'doi': summary['ArticleIds']['doi'], 'citations' : citations_from_doi(summary['ArticleIds']['doi']) }
    except:
        return {'uid':summary['Id'], 'EPubDate': summary['EPubDate'], 'doi': None, 'citations' : None }

# %%
result_citations = [ extract_epub_doi(summary[0]) for summary in result_summaries ]
result_citations
# Out:
# [{'uid': '34060442', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34059550',
#   'EPubDate': '2021 May 31',
#   'doi': None,
#   'citations': None},
#  {'uid': '34059544',
#   'EPubDate': '2021 May 31',
#   'doi': None,
#   'citations': None},
#  {'uid': '34059043',
#   'EPubDate': '2021 May 31',
#   'doi': None,
#   'citations': None},
#  {'uid': '34059036',
#   'EPubDate': '2021 May 31',
#   'doi': None,
#   'citations': None},
#  {'uid': '34059034',
#   'EPubDate': '2021 May 31',
#   'doi': None,
#   'citations': None},
#  {'uid': '34059031', 'EPubDate': '2021 Jun 1', 'doi': None, 'citations': None},
#  {'uid': '34058989',
#   'EPubDate': '2021 May 31',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055314',
#   'EPubDate': '2021 Feb 10',
#   'doi': None,
#   'citations': None},
#  {'uid': '34057973', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34057958', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34057361',
#   'EPubDate': '2021 Mar 23',
#   'doi': None,
#   'citations': None},
#  {'uid': '34057360',
#   'EPubDate': '2021 Mar 23',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055733',
#   'EPubDate': '2021 May 14',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055732',
#   'EPubDate': '2021 May 13',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055731',
#   'EPubDate': '2021 May 14',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055729',
#   'EPubDate': '2021 May 14',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055726',
#   'EPubDate': '2021 May 13',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055725',
#   'EPubDate': '2021 May 12',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055724',
#   'EPubDate': '2021 May 13',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055717',
#   'EPubDate': '2021 May 12',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055716',
#   'EPubDate': '2021 May 13',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055711',
#   'EPubDate': '2021 May 13',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055710',
#   'EPubDate': '2021 May 12',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055709',
#   'EPubDate': '2021 May 13',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055708',
#   'EPubDate': '2021 May 13',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055706',
#   'EPubDate': '2021 May 13',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055704',
#   'EPubDate': '2021 May 14',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055703',
#   'EPubDate': '2021 May 12',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055329',
#   'EPubDate': '2021 May 11',
#   'doi': None,
#   'citations': None},
#  {'uid': '34055328',
#   'EPubDate': '2021 May 22',
#   'doi': None,
#   'citations': None},
#  {'uid': '34053480', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34053479', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34053446',
#   'EPubDate': '2021 May 30',
#   'doi': None,
#   'citations': None},
#  {'uid': '34053442',
#   'EPubDate': '2021 May 30',
#   'doi': None,
#   'citations': None},
#  {'uid': '34053350', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34051956',
#   'EPubDate': '2021 Jan 25',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051952', 'EPubDate': '2021 Feb 5', 'doi': None, 'citations': None},
#  {'uid': '34051823',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051791',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051784',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051770',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051769',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051768',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051760',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051739',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34051723', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34046170', 'EPubDate': '2020 May 4', 'doi': None, 'citations': None},
#  {'uid': '34050295',
#   'EPubDate': '2021 May 28',
#   'doi': None,
#   'citations': None},
#  {'uid': '34050294',
#   'EPubDate': '2021 May 28',
#   'doi': None,
#   'citations': None},
#  {'uid': '34049895',
#   'EPubDate': '2021 May 28',
#   'doi': None,
#   'citations': None},
#  {'uid': '34049605', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34049602', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34049584',
#   'EPubDate': '2021 May 28',
#   'doi': None,
#   'citations': None},
#  {'uid': '34049573',
#   'EPubDate': '2021 May 28',
#   'doi': None,
#   'citations': None},
#  {'uid': '34049526',
#   'EPubDate': '2021 May 28',
#   'doi': None,
#   'citations': None},
#  {'uid': '34049525',
#   'EPubDate': '2021 May 29',
#   'doi': None,
#   'citations': None},
#  {'uid': '34049515',
#   'EPubDate': '2021 May 28',
#   'doi': None,
#   'citations': None},
#  {'uid': '34049513',
#   'EPubDate': '2021 May 28',
#   'doi': None,
#   'citations': None},
#  {'uid': '34048161',
#   'EPubDate': '2021 May 1',
#   'doi': '10.31557/APJCP.2021.22.5.1333',
#   'citations': 0},
#  {'uid': '34047274', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34047271', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34047040', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34047035', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34047034',
#   'EPubDate': '',
#   'doi': '10.1111/imj.14977',
#   'citations': 0},
#  {'uid': '34047031',
#   'EPubDate': '',
#   'doi': '10.1111/imj.15328',
#   'citations': 0},
#  {'uid': '34047029', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34047023',
#   'EPubDate': '',
#   'doi': '10.1111/imj.15217',
#   'citations': 0},
#  {'uid': '34047021', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34046393',
#   'EPubDate': '2021 May 11',
#   'doi': None,
#   'citations': None},
#  {'uid': '34046392',
#   'EPubDate': '2021 May 11',
#   'doi': None,
#   'citations': None},
#  {'uid': '34046391',
#   'EPubDate': '2021 May 11',
#   'doi': None,
#   'citations': None},
#  {'uid': '34046389',
#   'EPubDate': '2021 May 11',
#   'doi': None,
#   'citations': None},
#  {'uid': '34046388',
#   'EPubDate': '2021 May 11',
#   'doi': '10.3389/fpubh.2021.646568',
#   'citations': 0},
#  {'uid': '34046387',
#   'EPubDate': '2021 May 11',
#   'doi': '10.3389/fpubh.2021.622677',
#   'citations': 0},
#  {'uid': '34046384',
#   'EPubDate': '2021 May 11',
#   'doi': '10.3389/fpubh.2021.610280',
#   'citations': 0},
#  {'uid': '34046381',
#   'EPubDate': '2021 May 11',
#   'doi': '10.3389/fpubh.2021.598302',
#   'citations': 0},
#  {'uid': '34046379',
#   'EPubDate': '2021 May 11',
#   'doi': '10.3389/fpubh.2021.570147',
#   'citations': 0},
#  {'uid': '34046240',
#   'EPubDate': '2020 Nov 13',
#   'doi': '10.5365/wpsar.2020.11.1.012',
#   'citations': 0},
#  {'uid': '34046165',
#   'EPubDate': '2021 Apr 6',
#   'doi': '10.12688/f1000research.51786.1',
#   'citations': 0},
#  {'uid': '34045206',
#   'EPubDate': '2021 May 27',
#   'doi': None,
#   'citations': None},
#  {'uid': '34044998',
#   'EPubDate': '',
#   'doi': '10.1016/S2589-7500(21)00085-6',
#   'citations': 0},
#  {'uid': '34044979',
#   'EPubDate': '2021 Apr 15',
#   'doi': None,
#   'citations': None},
#  {'uid': '34044977',
#   'EPubDate': '',
#   'doi': '10.1016/j.adaj.2021.02.013',
#   'citations': 0},
#  {'uid': '34044976',
#   'EPubDate': '2021 Mar 2',
#   'doi': '10.1016/j.adaj.2021.02.009',
#   'citations': 0},
#  {'uid': '34044974',
#   'EPubDate': '',
#   'doi': '10.1016/j.adaj.2021.03.021',
#   'citations': 0},
#  {'uid': '34044965',
#   'EPubDate': '2021 Apr 23',
#   'doi': '10.1016/j.adaj.2021.04.012',
#   'citations': 0},
#  {'uid': '34044839',
#   'EPubDate': '2021 May 27',
#   'doi': '10.1186/s12911-021-01537-3',
#   'citations': 0},
#  {'uid': '34044831',
#   'EPubDate': '2021 May 27',
#   'doi': '10.1186/s12902-021-00766-x',
#   'citations': 0},
#  {'uid': '34044800',
#   'EPubDate': '2021 May 27',
#   'doi': '10.1186/s12887-021-02731-y',
#   'citations': 0},
#  {'uid': '34044790',
#   'EPubDate': '2021 May 27',
#   'doi': '10.1186/s12889-021-10902-w',
#   'citations': 0},
#  {'uid': '34044784',
#   'EPubDate': '2021 May 27',
#   'doi': '10.1186/s12879-021-06218-0',
#   'citations': 0},
#  {'uid': '34044777',
#   'EPubDate': '2021 May 27',
#   'doi': '10.1186/s12879-021-06164-x',
#   'citations': 0},
#  {'uid': '34044758',
#   'EPubDate': '2021 May 27',
#   'doi': '10.1186/s12879-021-06202-8',
#   'citations': 0},
#  {'uid': '34035906',
#   'EPubDate': '2020 Nov 20',
#   'doi': '10.12688/f1000research.27324.2',
#   'citations': 0},
#  {'uid': '34043615',
#   'EPubDate': '2021 May 28',
#   'doi': '10.15585/mmwr.mm7021e3',
#   'citations': 0},
#  {'uid': '34043614',
#   'EPubDate': '2021 May 28',
#   'doi': '10.15585/mmwr.mm7021e2',
#   'citations': 0},
#  {'uid': '34043613',
#   'EPubDate': '2021 May 28',
#   'doi': '10.15585/mmwr.mm7021a3',
#   'citations': 0},
#  {'uid': '34043610',
#   'EPubDate': '2021 May 28',
#   'doi': '10.15585/mmwr.mm7021e1',
#   'citations': 0},
#  {'uid': '34043219', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042868',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210375',
#   'citations': 0},
#  {'uid': '34042856',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210363',
#   'citations': 0},
#  {'uid': '34042853',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210360',
#   'citations': 0},
#  {'uid': '34042837',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210343',
#   'citations': 0},
#  {'uid': '34042836',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210342',
#   'citations': 0},
#  {'uid': '34042834',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210339',
#   'citations': 0},
#  {'uid': '34042825',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210330',
#   'citations': 0},
#  {'uid': '34042823',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210328',
#   'citations': 0},
#  {'uid': '34042821',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210326',
#   'citations': 0},
#  {'uid': '34042817',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210322',
#   'citations': 0},
#  {'uid': '34042815',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210320',
#   'citations': 0},
#  {'uid': '34042812',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210317',
#   'citations': 0},
#  {'uid': '34042804',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210309',
#   'citations': 0},
#  {'uid': '34042803',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210308',
#   'citations': 0},
#  {'uid': '34042800',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210305',
#   'citations': 0},
#  {'uid': '34042798',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210303',
#   'citations': 0},
#  {'uid': '34042797',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210302',
#   'citations': 0},
#  {'uid': '34042789',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210293',
#   'citations': 0},
#  {'uid': '34042787',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210291',
#   'citations': 0},
#  {'uid': '34042783',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210198',
#   'citations': 0},
#  {'uid': '34042775',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210190',
#   'citations': 0},
#  {'uid': '34042772',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210187',
#   'citations': 0},
#  {'uid': '34042760',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210175',
#   'citations': 0},
#  {'uid': '34042733',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210148',
#   'citations': 0},
#  {'uid': '34042715',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210130',
#   'citations': 0},
#  {'uid': '34042711',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210126',
#   'citations': 0},
#  {'uid': '34042709',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210124',
#   'citations': 0},
#  {'uid': '34042704',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210119',
#   'citations': 0},
#  {'uid': '34042699',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210114',
#   'citations': 0},
#  {'uid': '34042692',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210289',
#   'citations': 0},
#  {'uid': '34042690', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042689', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042688',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210285',
#   'citations': 0},
#  {'uid': '34042687', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042681', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042680', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042675', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042674', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042673', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042670', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042668',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210264',
#   'citations': 0},
#  {'uid': '34042665',
#   'EPubDate': '',
#   'doi': '10.3233/SHTI210261',
#   'citations': 0},
#  {'uid': '34042634', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042631', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042629', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042627', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042335', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042296', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34042089',
#   'EPubDate': '2021 Dec 21',
#   'doi': None,
#   'citations': None},
#  {'uid': '34041219',
#   'EPubDate': '2021 May 10',
#   'doi': None,
#   'citations': None},
#  {'uid': '34041218',
#   'EPubDate': '2021 May 10',
#   'doi': '10.3389/fpubh.2021.668153',
#   'citations': 0},
#  {'uid': '34041217',
#   'EPubDate': '2021 May 10',
#   'doi': None,
#   'citations': None},
#  {'uid': '34041216',
#   'EPubDate': '2021 May 10',
#   'doi': '10.3389/fpubh.2021.660064',
#   'citations': 0},
#  {'uid': '34041215', 'EPubDate': '2021 May 7', 'doi': None, 'citations': None},
#  {'uid': '34041213',
#   'EPubDate': '2021 May 10',
#   'doi': None,
#   'citations': None},
#  {'uid': '34040326', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34040321', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34040272',
#   'EPubDate': '2020 Jul 11',
#   'doi': None,
#   'citations': None},
#  {'uid': '34040221', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34040213',
#   'EPubDate': '',
#   'doi': '10.1038/d41586-021-01386-0',
#   'citations': 0},
#  {'uid': '34040204', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34039810', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34039799', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34039766', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34039764', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34039763', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34039654', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34039588', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34039585',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039579',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039574',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039554',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039547',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039345',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039344',
#   'EPubDate': '2021 May 27',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039323',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039313',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039306',
#   'EPubDate': '2021 May 27',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039292',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039289',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34039179', 'EPubDate': '2021 Apr 1', 'doi': None, 'citations': None},
#  {'uid': '34039139', 'EPubDate': '2021 May 1', 'doi': None, 'citations': None},
#  {'uid': '33968364',
#   'EPubDate': '2021 Feb 18',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038655', 'EPubDate': '2021 Mar 1', 'doi': None, 'citations': None},
#  {'uid': '34038475',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038459',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038453',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038444',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038425',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038423',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038260', 'EPubDate': '2021 Apr 1', 'doi': None, 'citations': None},
#  {'uid': '34038167',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038165',
#   'EPubDate': '2021 May 26',
#   'doi': None,
#   'citations': None},
#  {'uid': '34038035',
#   'EPubDate': '2020 Dec 23',
#   'doi': None,
#   'citations': None},
#  {'uid': '34037734', 'EPubDate': '2021 May 3', 'doi': None, 'citations': None},
#  {'uid': '34037733', 'EPubDate': '2021 May 3', 'doi': None, 'citations': None},
#  {'uid': '34037731', 'EPubDate': '2021 May 3', 'doi': None, 'citations': None},
#  {'uid': '34037598', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34037551', 'EPubDate': '', 'doi': None, 'citations': None},
#  {'uid': '34037548', 'EPubDate': '', 'doi': None, 'citations': None}]

# %%
result_citations = pd.DataFrame(result_citations)
result_citations
# Out:
#           uid     EPubDate   doi  citations
# 0    34060442               None        NaN
# 1    34059550  2021 May 31  None        NaN
# 2    34059544  2021 May 31  None        NaN
# 3    34059043  2021 May 31  None        NaN
# 4    34059036  2021 May 31  None        NaN
# ..        ...          ...   ...        ...
# 195  34037733   2021 May 3  None        NaN
# 196  34037731   2021 May 3  None        NaN
# 197  34037598               None        NaN
# 198  34037551               None        NaN
# 199  34037548               None        NaN
#
# [200 rows x 4 columns]

# %% [markdown]
# # Abstracts

# %%
## Abstract
results_abstracts = entrez_construct_abstract_dict(uids,"XXX@YYY.com")

# %%
len(results_abstracts)
# Out:
# 169

# %%
results_abstracts = pd.DataFrame(results_abstracts)
results_abstracts
# Out:
#           uid                                           abstract include
# 0    34060442  Objective To predict the epitopes of B cells, ...
# 1    34059550  We report a case of COVID-19 in a 29-week pret...
# 2    34059544  Immune thrombocytopenia (ITP) has been widely ...
# 3    34059043   BACKGROUND: The media play a critical role in...
# 4    34059036   OBJECTIVES: The second wave of the coronaviru...
# ..        ...                                                ...     ...
# 164  34039764  Regular surveillance testing of asymptomatic i...
# 165  34039763  SARS-CoV-2 infection in minks has become a ser...
# 166  34039654  The COVID-19 pandemic has brought biosafety to...
# 167  34039588   Importance: Infection with COVID-19 has been ...
# 168  34039585   ABSTRACT: In this study, we evaluated whether...
#
# [169 rows x 3 columns]

# %% [markdown]
# # Merge

# %%
df_merged = pd.merge(results_abstracts,result_citations)
df_merged
# Out:
#           uid                                           abstract include  \
# 0    34060442  Objective To predict the epitopes of B cells, ...
# 1    34059550  We report a case of COVID-19 in a 29-week pret...
# 2    34059544  Immune thrombocytopenia (ITP) has been widely ...
# 3    34059043   BACKGROUND: The media play a critical role in...
# 4    34059036   OBJECTIVES: The second wave of the coronaviru...
# ..        ...                                                ...     ...
# 164  34039764  Regular surveillance testing of asymptomatic i...
# 165  34039763  SARS-CoV-2 infection in minks has become a ser...
# 166  34039654  The COVID-19 pandemic has brought biosafety to...
# 167  34039588   Importance: Infection with COVID-19 has been ...
# 168  34039585   ABSTRACT: In this study, we evaluated whether...
#
#         EPubDate   doi  citations
# 0                 None        NaN
# 1    2021 May 31  None        NaN
# 2    2021 May 31  None        NaN
# 3    2021 May 31  None        NaN
# 4    2021 May 31  None        NaN
# ..           ...   ...        ...
# 164               None        NaN
# 165               None        NaN
# 166               None        NaN
# 167               None        NaN
# 168  2021 May 26  None        NaN
#
# [169 rows x 6 columns]

# %% [markdown]
# # To Excel

# %%
df_merged.to_excel("COVID_SELECTION.xlsx")
